# %% [markdown]
# ## **1. Import Libraries**

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# Calculate execution time
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Extract data from Drive
# !pip install patool
import patoolib
patoolib.extract_archive('/content/drive/MyDrive/kolapo/images.rar')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 4.5 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-1.12
# patool: Extracting /content/drive/MyDrive/kolapo/images.rar ...
# patool: running /usr/bin/unrar x -- /content/drive/MyDrive/kolapo/images.rar
# patool:     with cwd='./Unpack_c4lxh_al'
# patool: ... /content/drive/MyDrive/kolapo/images.rar extracted to `images'.
# 'images'

# %% [markdown]
# # 2. Set Parameters

# %%
# declare path
train_dir = '/content/images/train'
test_dir = '/content/images/validation/'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)
BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare Data

# %%
# Data augmentation

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
# Load dataset

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS,
                                                   shuffle = True)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =False,
                                                  batch_size = BS)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore Dataset

# %%
# Total train/val sample
def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = os.path.join(path, expression)
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

HTML(train_count.append(test_count).to_html(escape=False))
# Out:
# <ipython-input-7-fb6ab70decb2>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   HTML(train_count.append(test_count).to_html(escape=False))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>fear</th>
#       <th>surprise</th>
#       <th>angry</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>4982</td>
#       <td>4938</td>
#       <td>4103</td>
#       <td>3205</td>
#       <td>3993</td>
#       <td>436</td>
#       <td>7164</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>1216</td>
#       <td>1139</td>
#       <td>1018</td>
#       <td>797</td>
#       <td>960</td>
#       <td>111</td>
#       <td>1825</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img(os.path.join(train_dir, expression, os.listdir(os.path.join(train_dir, expression))[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
# Plot distribution of train/test dataste per class

x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %% [markdown]
# # 5. Model

# %%
# VGG16

base_model = tf.keras.applications.VGG16(input_shape= IMAGE_SHAPE,include_top=False,weights="imagenet")
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 48, 48, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 48, 48, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 24, 24, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 24, 24, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 24, 24, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:11]:
    layer.trainable=False

# %%
# Model trainable

print("Model trainable",len(base_model.trainable_variables))
# Out:
# Model trainable 12

# %%
# Build transfer learning Model

model=Sequential()
model.add(base_model)
model.add(BatchNormalization())
model.add(GaussianNoise(0.01))
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  batch_normalization (BatchN  (None, 1, 1, 512)        2048
#  ormalization)
#
#  gaussian_noise (GaussianNoi  (None, 1, 1, 512)        0
#  se)
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 14,883,399
# Trainable params: 13,146,119
# Non-trainable params: 1,737,280
# _________________________________________________________________

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

# adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
adam = tf.keras.optimizers.legacy.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
#starting time
start = time.time()

# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)

# end time
end = time.time()

# total time taken
print("Execution time of the program is- ", end - start)
# Out:
# Epoch 1/100
# 451/451 [==============================] - 77s 142ms/step - loss: 5.1362 - accuracy: 0.8192 - precision: 0.2169 - recall: 0.1017 - auc: 0.5647 - f1_score: 0.1384 - val_loss: 3.9697 - val_accuracy: 0.8081 - val_precision: 0.2584 - val_recall: 0.1837 - val_auc: 0.5727 - val_f1_score: 0.2122 - lr: 1.0000e-04
# Epoch 2/100
# 451/451 [==============================] - 48s 107ms/step - loss: 4.3921 - accuracy: 0.8349 - precision: 0.3197 - recall: 0.1379 - auc: 0.6378 - f1_score: 0.1922 - val_loss: 3.3267 - val_accuracy: 0.8217 - val_precision: 0.2603 - val_recall: 0.1346 - val_auc: 0.5396 - val_f1_score: 0.1638 - lr: 1.0000e-04
# Epoch 3/100
# 451/451 [==============================] - 48s 105ms/step - loss: 3.9475 - accuracy: 0.8494 - precision: 0.4327 - recall: 0.1745 - auc: 0.6903 - f1_score: 0.2482 - val_loss: 3.5097 - val_accuracy: 0.8316 - val_precision: 0.3467 - val_recall: 0.2021 - val_auc: 0.6245 - val_f1_score: 0.2407 - lr: 1.0000e-04
# Epoch 4/100
# 451/451 [==============================] - 50s 110ms/step - loss: 3.6354 - accuracy: 0.8587 - precision: 0.5152 - recall: 0.1882 - auc: 0.7219 - f1_score: 0.2745 - val_loss: 2.2031 - val_accuracy: 0.8708 - val_precision: 0.5973 - val_recall: 0.2928 - val_auc: 0.7886 - val_f1_score: 0.3279 - lr: 1.0000e-04
# Epoch 5/100
# 451/451 [==============================] - 48s 106ms/step - loss: 3.3918 - accuracy: 0.8640 - precision: 0.5668 - recall: 0.2037 - auc: 0.7537 - f1_score: 0.2989 - val_loss: 2.1093 - val_accuracy: 0.8708 - val_precision: 0.5909 - val_recall: 0.3111 - val_auc: 0.7993 - val_f1_score: 0.3486 - lr: 1.0000e-04
# Epoch 6/100
# 451/451 [==============================] - 49s 109ms/step - loss: 3.2039 - accuracy: 0.8688 - precision: 0.6114 - recall: 0.2237 - auc: 0.7804 - f1_score: 0.3264 - val_loss: 1.9412 - val_accuracy: 0.8819 - val_precision: 0.6654 - val_recall: 0.3481 - val_auc: 0.8234 - val_f1_score: 0.4019 - lr: 1.0000e-04
# Epoch 7/100
# 451/451 [==============================] - 48s 105ms/step - loss: 3.0707 - accuracy: 0.8719 - precision: 0.6357 - recall: 0.2416 - auc: 0.7977 - f1_score: 0.3492 - val_loss: 1.8844 - val_accuracy: 0.8757 - val_precision: 0.6618 - val_recall: 0.2656 - val_auc: 0.8201 - val_f1_score: 0.3451 - lr: 1.0000e-04
# Epoch 8/100
# 451/451 [==============================] - 48s 106ms/step - loss: 2.9739 - accuracy: 0.8737 - precision: 0.6428 - recall: 0.2604 - auc: 0.8110 - f1_score: 0.3696 - val_loss: 1.8828 - val_accuracy: 0.8757 - val_precision: 0.6674 - val_recall: 0.2593 - val_auc: 0.8228 - val_f1_score: 0.3284 - lr: 1.0000e-04
# Epoch 9/100
# 451/451 [==============================] - 49s 108ms/step - loss: 2.8573 - accuracy: 0.8776 - precision: 0.6688 - recall: 0.2839 - auc: 0.8250 - f1_score: 0.3975 - val_loss: 2.6346 - val_accuracy: 0.8219 - val_precision: 0.3352 - val_recall: 0.2511 - val_auc: 0.7310 - val_f1_score: 0.2789 - lr: 1.0000e-04
# Epoch 10/100
# 451/451 [==============================] - 49s 108ms/step - loss: 2.7331 - accuracy: 0.8806 - precision: 0.6836 - recall: 0.3057 - auc: 0.8379 - f1_score: 0.4217 - val_loss: 1.7414 - val_accuracy: 0.8819 - val_precision: 0.6772 - val_recall: 0.3313 - val_auc: 0.8492 - val_f1_score: 0.4214 - lr: 1.0000e-04
# Epoch 11/100
# 451/451 [==============================] - 47s 104ms/step - loss: 2.6966 - accuracy: 0.8809 - precision: 0.6831 - recall: 0.3096 - auc: 0.8426 - f1_score: 0.4253 - val_loss: 1.7774 - val_accuracy: 0.8792 - val_precision: 0.6754 - val_recall: 0.2968 - val_auc: 0.8380 - val_f1_score: 0.3766 - lr: 1.0000e-04
# Epoch 12/100
# 451/451 [==============================] - 46s 103ms/step - loss: 2.6009 - accuracy: 0.8829 - precision: 0.6919 - recall: 0.3248 - auc: 0.8523 - f1_score: 0.4411 - val_loss: 1.6284 - val_accuracy: 0.8890 - val_precision: 0.6765 - val_recall: 0.4274 - val_auc: 0.8751 - val_f1_score: 0.4841 - lr: 1.0000e-04
# Epoch 13/100
# 451/451 [==============================] - 49s 108ms/step - loss: 2.5121 - accuracy: 0.8857 - precision: 0.7009 - recall: 0.3491 - auc: 0.8618 - f1_score: 0.4651 - val_loss: 1.8277 - val_accuracy: 0.8756 - val_precision: 0.6474 - val_recall: 0.2835 - val_auc: 0.8205 - val_f1_score: 0.3813 - lr: 1.0000e-04
# Epoch 14/100
# 451/451 [==============================] - 47s 103ms/step - loss: 2.4384 - accuracy: 0.8870 - precision: 0.7038 - recall: 0.3609 - auc: 0.8677 - f1_score: 0.4764 - val_loss: 1.9846 - val_accuracy: 0.8700 - val_precision: 0.6003 - val_recall: 0.2702 - val_auc: 0.7867 - val_f1_score: 0.3481 - lr: 1.0000e-04
# Epoch 15/100
# 451/451 [==============================] - 47s 104ms/step - loss: 2.3903 - accuracy: 0.8891 - precision: 0.7116 - recall: 0.3764 - auc: 0.8714 - f1_score: 0.4915 - val_loss: 1.5022 - val_accuracy: 0.8942 - val_precision: 0.7384 - val_recall: 0.4022 - val_auc: 0.8911 - val_f1_score: 0.4815 - lr: 1.0000e-04
# Epoch 16/100
# 451/451 [==============================] - 48s 107ms/step - loss: 2.2841 - accuracy: 0.8921 - precision: 0.7249 - recall: 0.3947 - auc: 0.8819 - f1_score: 0.5103 - val_loss: 1.5527 - val_accuracy: 0.8919 - val_precision: 0.7069 - val_recall: 0.4154 - val_auc: 0.8774 - val_f1_score: 0.4872 - lr: 1.0000e-04
# Epoch 17/100
# 451/451 [==============================] - 49s 109ms/step - loss: 2.2570 - accuracy: 0.8927 - precision: 0.7244 - recall: 0.4018 - auc: 0.8833 - f1_score: 0.5159 - val_loss: 1.5551 - val_accuracy: 0.8871 - val_precision: 0.6735 - val_recall: 0.4067 - val_auc: 0.8747 - val_f1_score: 0.4834 - lr: 1.0000e-04
# Epoch 18/100
# 451/451 [==============================] - 48s 107ms/step - loss: 2.1806 - accuracy: 0.8955 - precision: 0.7326 - recall: 0.4226 - auc: 0.8899 - f1_score: 0.5352 - val_loss: 1.5176 - val_accuracy: 0.8928 - val_precision: 0.6876 - val_recall: 0.4570 - val_auc: 0.8819 - val_f1_score: 0.5240 - lr: 1.0000e-04
# Epoch 19/100
# 451/451 [==============================] - 48s 106ms/step - loss: 2.1347 - accuracy: 0.8970 - precision: 0.7379 - recall: 0.4330 - auc: 0.8937 - f1_score: 0.5449 - val_loss: 1.3811 - val_accuracy: 0.8983 - val_precision: 0.7250 - val_recall: 0.4638 - val_auc: 0.9010 - val_f1_score: 0.5474 - lr: 1.0000e-04
# Epoch 20/100
# 451/451 [==============================] - 48s 107ms/step - loss: 2.0767 - accuracy: 0.8981 - precision: 0.7376 - recall: 0.4449 - auc: 0.8970 - f1_score: 0.5541 - val_loss: 1.4209 - val_accuracy: 0.8956 - val_precision: 0.7116 - val_recall: 0.4530 - val_auc: 0.8928 - val_f1_score: 0.5280 - lr: 1.0000e-04
# Epoch 21/100
# 451/451 [==============================] - 48s 106ms/step - loss: 1.9976 - accuracy: 0.9012 - precision: 0.7471 - recall: 0.4663 - auc: 0.9040 - f1_score: 0.5730 - val_loss: 1.5120 - val_accuracy: 0.8887 - val_precision: 0.6803 - val_recall: 0.4171 - val_auc: 0.8729 - val_f1_score: 0.4994 - lr: 1.0000e-04
# Epoch 22/100
# 451/451 [==============================] - 47s 104ms/step - loss: 1.9238 - accuracy: 0.9035 - precision: 0.7517 - recall: 0.4847 - auc: 0.9099 - f1_score: 0.5887 - val_loss: 1.4247 - val_accuracy: 0.8924 - val_precision: 0.7068 - val_recall: 0.4223 - val_auc: 0.8859 - val_f1_score: 0.5088 - lr: 1.0000e-04
# Epoch 23/100
# 451/451 [==============================] - 47s 103ms/step - loss: 1.9034 - accuracy: 0.9039 - precision: 0.7490 - recall: 0.4919 - auc: 0.9109 - f1_score: 0.5931 - val_loss: 1.2881 - val_accuracy: 0.9026 - val_precision: 0.7380 - val_recall: 0.4936 - val_auc: 0.9096 - val_f1_score: 0.5783 - lr: 1.0000e-04
# Epoch 24/100
# 451/451 [==============================] - 47s 105ms/step - loss: 1.8327 - accuracy: 0.9073 - precision: 0.7606 - recall: 0.5124 - auc: 0.9173 - f1_score: 0.6113 - val_loss: 1.3114 - val_accuracy: 0.9027 - val_precision: 0.7383 - val_recall: 0.4943 - val_auc: 0.9049 - val_f1_score: 0.5673 - lr: 1.0000e-04
# Epoch 25/100
# 451/451 [==============================] - 48s 106ms/step - loss: 1.7868 - accuracy: 0.9085 - precision: 0.7635 - recall: 0.5207 - auc: 0.9207 - f1_score: 0.6186 - val_loss: 1.2760 - val_accuracy: 0.9023 - val_precision: 0.7215 - val_recall: 0.5149 - val_auc: 0.9103 - val_f1_score: 0.5897 - lr: 1.0000e-04
# Epoch 26/100
# 451/451 [==============================] - 48s 106ms/step - loss: 1.7448 - accuracy: 0.9101 - precision: 0.7659 - recall: 0.5334 - auc: 0.9245 - f1_score: 0.6282 - val_loss: 1.2616 - val_accuracy: 0.9030 - val_precision: 0.7338 - val_recall: 0.5041 - val_auc: 0.9104 - val_f1_score: 0.5843 - lr: 1.0000e-04
# Epoch 27/100
# 451/451 [==============================] - 46s 102ms/step - loss: 1.6954 - accuracy: 0.9129 - precision: 0.7723 - recall: 0.5540 - auc: 0.9272 - f1_score: 0.6446 - val_loss: 1.3750 - val_accuracy: 0.8953 - val_precision: 0.6776 - val_recall: 0.5099 - val_auc: 0.8942 - val_f1_score: 0.5715 - lr: 1.0000e-04
# Epoch 28/100
# 451/451 [==============================] - 46s 102ms/step - loss: 1.6229 - accuracy: 0.9157 - precision: 0.7802 - recall: 0.5708 - auc: 0.9335 - f1_score: 0.6587 - val_loss: 1.3143 - val_accuracy: 0.9003 - val_precision: 0.7020 - val_recall: 0.5253 - val_auc: 0.9014 - val_f1_score: 0.5902 - lr: 1.0000e-04
# Epoch 29/100
# 451/451 [==============================] - 48s 107ms/step - loss: 1.5847 - accuracy: 0.9176 - precision: 0.7830 - recall: 0.5859 - auc: 0.9361 - f1_score: 0.6696 - val_loss: 1.2548 - val_accuracy: 0.9036 - val_precision: 0.7203 - val_recall: 0.5313 - val_auc: 0.9099 - val_f1_score: 0.6023 - lr: 1.0000e-04
# Epoch 30/100
# 451/451 [==============================] - 47s 103ms/step - loss: 1.5361 - accuracy: 0.9205 - precision: 0.7917 - recall: 0.6022 - auc: 0.9394 - f1_score: 0.6833 - val_loss: 1.2910 - val_accuracy: 0.8992 - val_precision: 0.6977 - val_recall: 0.5191 - val_auc: 0.9041 - val_f1_score: 0.5834 - lr: 1.0000e-04
# Epoch 31/100
# 451/451 [==============================] - 48s 106ms/step - loss: 1.4953 - accuracy: 0.9215 - precision: 0.7902 - recall: 0.6135 - auc: 0.9417 - f1_score: 0.6901 - val_loss: 1.5678 - val_accuracy: 0.8859 - val_precision: 0.6352 - val_recall: 0.4725 - val_auc: 0.8635 - val_f1_score: 0.5352 - lr: 1.0000e-04
# Epoch 32/100
# 451/451 [==============================] - 47s 103ms/step - loss: 1.4502 - accuracy: 0.9241 - precision: 0.7991 - recall: 0.6262 - auc: 0.9449 - f1_score: 0.7016 - val_loss: 1.2616 - val_accuracy: 0.9023 - val_precision: 0.7071 - val_recall: 0.5398 - val_auc: 0.9080 - val_f1_score: 0.6010 - lr: 1.0000e-04
# Epoch 33/100
# 451/451 [==============================] - 46s 102ms/step - loss: 1.4149 - accuracy: 0.9261 - precision: 0.8025 - recall: 0.6401 - auc: 0.9476 - f1_score: 0.7115 - val_loss: 1.2948 - val_accuracy: 0.8993 - val_precision: 0.6891 - val_recall: 0.5376 - val_auc: 0.9022 - val_f1_score: 0.5971 - lr: 1.0000e-04
# Epoch 34/100
# 451/451 [==============================] - 48s 107ms/step - loss: 1.3645 - accuracy: 0.9283 - precision: 0.8086 - recall: 0.6522 - auc: 0.9510 - f1_score: 0.7211 - val_loss: 1.3112 - val_accuracy: 0.8975 - val_precision: 0.6823 - val_recall: 0.5282 - val_auc: 0.8988 - val_f1_score: 0.5894 - lr: 1.0000e-04
# Epoch 35/100
# 451/451 [==============================] - 46s 103ms/step - loss: 1.3232 - accuracy: 0.9311 - precision: 0.8137 - recall: 0.6715 - auc: 0.9538 - f1_score: 0.7353 - val_loss: 1.3619 - val_accuracy: 0.8941 - val_precision: 0.6587 - val_recall: 0.5367 - val_auc: 0.8968 - val_f1_score: 0.5834 - lr: 1.0000e-04
# Epoch 36/100
# 451/451 [==============================] - 49s 108ms/step - loss: 1.2617 - accuracy: 0.9338 - precision: 0.8215 - recall: 0.6852 - auc: 0.9572 - f1_score: 0.7466 - val_loss: 1.2851 - val_accuracy: 0.9015 - val_precision: 0.6816 - val_recall: 0.5826 - val_auc: 0.9085 - val_f1_score: 0.6253 - lr: 1.0000e-04
# Epoch 37/100
# 451/451 [==============================] - 48s 107ms/step - loss: 1.2443 - accuracy: 0.9342 - precision: 0.8197 - recall: 0.6915 - auc: 0.9585 - f1_score: 0.7497 - val_loss: 1.2425 - val_accuracy: 0.9038 - val_precision: 0.7000 - val_recall: 0.5713 - val_auc: 0.9111 - val_f1_score: 0.6246 - lr: 1.0000e-04
# Epoch 38/100
# 451/451 [==============================] - 47s 105ms/step - loss: 1.1929 - accuracy: 0.9375 - precision: 0.8291 - recall: 0.7086 - auc: 0.9613 - f1_score: 0.7640 - val_loss: 1.4826 - val_accuracy: 0.8897 - val_precision: 0.6399 - val_recall: 0.5214 - val_auc: 0.8775 - val_f1_score: 0.5684 - lr: 1.0000e-04
# Epoch 39/100
# 451/451 [==============================] - 46s 103ms/step - loss: 1.1528 - accuracy: 0.9398 - precision: 0.8345 - recall: 0.7219 - auc: 0.9641 - f1_score: 0.7737 - val_loss: 1.3576 - val_accuracy: 0.8961 - val_precision: 0.6637 - val_recall: 0.5528 - val_auc: 0.8956 - val_f1_score: 0.5982 - lr: 1.0000e-04
# Epoch 40/100
# 451/451 [==============================] - 47s 103ms/step - loss: 1.1085 - accuracy: 0.9420 - precision: 0.8396 - recall: 0.7338 - auc: 0.9664 - f1_score: 0.7828 - val_loss: 1.2753 - val_accuracy: 0.9033 - val_precision: 0.6859 - val_recall: 0.5958 - val_auc: 0.9097 - val_f1_score: 0.6351 - lr: 1.0000e-04
# Epoch 41/100
# 451/451 [==============================] - 46s 102ms/step - loss: 1.0570 - accuracy: 0.9443 - precision: 0.8452 - recall: 0.7466 - auc: 0.9692 - f1_score: 0.7925 - val_loss: 1.3748 - val_accuracy: 0.8961 - val_precision: 0.6597 - val_recall: 0.5634 - val_auc: 0.8963 - val_f1_score: 0.6034 - lr: 1.0000e-04
# Epoch 42/100
# 451/451 [==============================] - 46s 103ms/step - loss: 1.0051 - accuracy: 0.9470 - precision: 0.8513 - recall: 0.7624 - auc: 0.9716 - f1_score: 0.8038 - val_loss: 1.3283 - val_accuracy: 0.9006 - val_precision: 0.6722 - val_recall: 0.5940 - val_auc: 0.9042 - val_f1_score: 0.6279 - lr: 1.0000e-04
# Epoch 43/100
# 451/451 [==============================] - 46s 101ms/step - loss: 1.0216 - accuracy: 0.9462 - precision: 0.8481 - recall: 0.7597 - auc: 0.9712 - f1_score: 0.8011 - val_loss: 1.2967 - val_accuracy: 0.9005 - val_precision: 0.6720 - val_recall: 0.5933 - val_auc: 0.9077 - val_f1_score: 0.6274 - lr: 1.0000e-04
# Epoch 44/100
# 451/451 [==============================] - 46s 101ms/step - loss: 0.9701 - accuracy: 0.9488 - precision: 0.8558 - recall: 0.7717 - auc: 0.9738 - f1_score: 0.8112 - val_loss: 1.2725 - val_accuracy: 0.9044 - val_precision: 0.6908 - val_recall: 0.5986 - val_auc: 0.9092 - val_f1_score: 0.6372 - lr: 1.0000e-04
# Epoch 45/100
# 451/451 [==============================] - 48s 107ms/step - loss: 0.9580 - accuracy: 0.9494 - precision: 0.8554 - recall: 0.7770 - auc: 0.9743 - f1_score: 0.8139 - val_loss: 1.3508 - val_accuracy: 0.8966 - val_precision: 0.6593 - val_recall: 0.5715 - val_auc: 0.8997 - val_f1_score: 0.6089 - lr: 1.0000e-04
# Epoch 46/100
# 451/451 [==============================] - 46s 102ms/step - loss: 0.8842 - accuracy: 0.9531 - precision: 0.8667 - recall: 0.7937 - auc: 0.9777 - f1_score: 0.8283 - val_loss: 1.3077 - val_accuracy: 0.9018 - val_precision: 0.6770 - val_recall: 0.5979 - val_auc: 0.9058 - val_f1_score: 0.6321 - lr: 1.0000e-04
# Epoch 47/100
# 451/451 [==============================] - ETA: 0s - loss: 0.9141 - accuracy: 0.9514 - precision: 0.8612 - recall: 0.7862 - auc: 0.9762 - f1_score: 0.8217
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 451/451 [==============================] - 47s 103ms/step - loss: 0.9141 - accuracy: 0.9514 - precision: 0.8612 - recall: 0.7862 - auc: 0.9762 - f1_score: 0.8217 - val_loss: 1.2775 - val_accuracy: 0.9036 - val_precision: 0.6830 - val_recall: 0.6064 - val_auc: 0.9087 - val_f1_score: 0.6386 - lr: 1.0000e-04
# Epoch 48/100
# 451/451 [==============================] - 47s 105ms/step - loss: 0.7306 - accuracy: 0.9626 - precision: 0.8935 - recall: 0.8377 - auc: 0.9847 - f1_score: 0.8644 - val_loss: 1.3296 - val_accuracy: 0.9046 - val_precision: 0.6806 - val_recall: 0.6261 - val_auc: 0.9075 - val_f1_score: 0.6505 - lr: 5.0000e-05
# Epoch 49/100
# 451/451 [==============================] - 46s 102ms/step - loss: 0.6509 - accuracy: 0.9670 - precision: 0.9038 - recall: 0.8608 - auc: 0.9876 - f1_score: 0.8815 - val_loss: 1.3815 - val_accuracy: 0.9026 - val_precision: 0.6722 - val_recall: 0.6214 - val_auc: 0.9040 - val_f1_score: 0.6443 - lr: 5.0000e-05
# Epoch 50/100
# 451/451 [==============================] - 45s 101ms/step - loss: 0.6360 - accuracy: 0.9682 - precision: 0.9058 - recall: 0.8678 - auc: 0.9882 - f1_score: 0.8862 - val_loss: 1.4070 - val_accuracy: 0.9009 - val_precision: 0.6649 - val_recall: 0.6173 - val_auc: 0.9027 - val_f1_score: 0.6392 - lr: 5.0000e-05
# Epoch 51/100
# 451/451 [==============================] - 46s 101ms/step - loss: 0.6302 - accuracy: 0.9684 - precision: 0.9057 - recall: 0.8692 - auc: 0.9884 - f1_score: 0.8868 - val_loss: 1.4346 - val_accuracy: 0.8977 - val_precision: 0.6538 - val_recall: 0.6032 - val_auc: 0.8987 - val_f1_score: 0.6259 - lr: 5.0000e-05
# Epoch 52/100
# 451/451 [==============================] - 46s 103ms/step - loss: 0.5975 - accuracy: 0.9706 - precision: 0.9117 - recall: 0.8791 - auc: 0.9893 - f1_score: 0.8949 - val_loss: 1.3911 - val_accuracy: 0.9006 - val_precision: 0.6635 - val_recall: 0.6173 - val_auc: 0.9024 - val_f1_score: 0.6382 - lr: 5.0000e-05
# Epoch 53/100
# 451/451 [==============================] - 46s 101ms/step - loss: 0.5605 - accuracy: 0.9725 - precision: 0.9177 - recall: 0.8869 - auc: 0.9903 - f1_score: 0.9018 - val_loss: 1.4383 - val_accuracy: 0.9023 - val_precision: 0.6673 - val_recall: 0.6308 - val_auc: 0.9012 - val_f1_score: 0.6478 - lr: 5.0000e-05
# Epoch 54/100
# 451/451 [==============================] - 45s 101ms/step - loss: 0.5442 - accuracy: 0.9738 - precision: 0.9210 - recall: 0.8930 - auc: 0.9908 - f1_score: 0.9067 - val_loss: 1.4271 - val_accuracy: 0.9029 - val_precision: 0.6698 - val_recall: 0.6316 - val_auc: 0.9003 - val_f1_score: 0.6489 - lr: 5.0000e-05
# Epoch 55/100
# 451/451 [==============================] - 48s 106ms/step - loss: 0.5483 - accuracy: 0.9730 - precision: 0.9185 - recall: 0.8901 - auc: 0.9910 - f1_score: 0.9039 - val_loss: 1.4592 - val_accuracy: 0.9015 - val_precision: 0.6644 - val_recall: 0.6269 - val_auc: 0.8976 - val_f1_score: 0.6440 - lr: 5.0000e-05
# Epoch 56/100
# 451/451 [==============================] - 45s 101ms/step - loss: 0.5332 - accuracy: 0.9740 - precision: 0.9203 - recall: 0.8951 - auc: 0.9912 - f1_score: 0.9075 - val_loss: 1.4566 - val_accuracy: 0.9013 - val_precision: 0.6629 - val_recall: 0.6291 - val_auc: 0.8976 - val_f1_score: 0.6451 - lr: 5.0000e-05
# Epoch 57/100
# 451/451 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.9747 - precision: 0.9235 - recall: 0.8969 - auc: 0.9919 - f1_score: 0.9100
# Epoch 57: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 451/451 [==============================] - 46s 101ms/step - loss: 0.5110 - accuracy: 0.9747 - precision: 0.9235 - recall: 0.8969 - auc: 0.9919 - f1_score: 0.9100 - val_loss: 1.4703 - val_accuracy: 0.9015 - val_precision: 0.6635 - val_recall: 0.6299 - val_auc: 0.8971 - val_f1_score: 0.6460 - lr: 5.0000e-05
# Epoch 57: early stopping
# Execution time of the program is-  3619.6145837306976

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# 6.1 Check some scores

# %%
#Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 451/451 [==============================] - 39s 86ms/step - loss: 0.3333 - accuracy: 0.9767 - precision: 0.9284 - recall: 0.9066 - auc: 0.9939 - f1_score: 0.9173
# 111/111 [==============================] - 3s 28ms/step - loss: 1.4703 - accuracy: 0.9015 - precision: 0.6635 - recall: 0.6299 - auc: 0.8971 - f1_score: 0.6460

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.333</td>
#       <td>1.470</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.977</td>
#       <td>0.902</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.928</td>
#       <td>0.664</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.907</td>
#       <td>0.630</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.994</td>
#       <td>0.897</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.917</td>
#       <td>0.646</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 6.2 Visualize result

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 111/111 [==============================] - 3s 27ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[ 494   17  119   43  146  127   14]
#  [  15   82    3    0    3    6    2]
#  [ 110   11  550   23  107  155   62]
#  [  48    5   53 1451  152   64   52]
#  [  78    1   74   85  761  186   31]
#  [  82   24  133   39  230  608   23]
#  [  15    4   79   33   31   20  615]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# ## **7. Save Model**

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.save('same_model.h5')

# %%
# Save to drive
# !cp -r 'model.json' /content/drive/MyDrive/kolapo/models
# !cp -r 'model.h5' /content/drive/MyDrive/kolapo/models
# !cp -r 'same_model.h5' /content/drive/MyDrive/kolapo/models

print('all done')
# Out:
# all done

# %% [markdown]
# ## **8. Predict**

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='/content/images/validation/happy/11345.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
# plt.imshow(test_image)
# plt.show()
# Out:
# (48, 48, 1)

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# 1/1 [==============================] - 0s 476ms/step
# [0. 0. 0. 0. 0. 1. 0.]
# The person facial emotion is: Sad
